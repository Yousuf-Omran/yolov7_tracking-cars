# %%
#!git clone https://github.com/WongKinYiu/yolov7
#%cd yolov7
#%pip install -r requirements.txt
import torch
import os

# %% [markdown]
# use next command if you run the code on the internet

# %%
#%cd /content/yolov7
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !python train.py --img 640 --epoch 100 --hyp data/hyp.scratch.p6.yaml --data {'D:\OneDrive\courses\ODC&AMIT hackathon\end-to-end project files\final data\train_valid_test'}/data.yaml --weights yolov7.pt --cache --name track_carss

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs

# %%
# !python detect.py --weights own_weights.pt --img 640 --conf 0.6 --source SWP2.mp4
# Out:
# Namespace(weights=['own_weights.pt'], source='vid2.mp4', img_size=640, conf_thres=0.6, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# video 1/1 (1/1238) d:\Documents\GitHub\yolov7_tracking-cars\vid2.mp4: 30 cars, Done. (2194.0ms) Inference, (313.1ms) NMS
# video 1/1 (2/1238) d:\Documents\GitHub\yolov7_tracking-cars\vid2.mp4: 29 cars, Done. (1002.8ms) Inference, (1.5ms) NMS
# video 1/1 (3/1238) d:\Documents\GitHub\yolov7_tracking-cars\vid2.mp4: 26 cars, Done. (906.1ms) Inference, (2.0ms) NMS
# video 1/1 (4/1238) d:\Documents\GitHub\yolov7_tracking-cars\vid2.mp4: 26 cars, Done. (907.6ms) Inference, (2.0ms) NMS
# ...

# %%
#from pickle import dump
#dump(tc_weights.pt,open('tc_weights.pt' ,'wb'))
